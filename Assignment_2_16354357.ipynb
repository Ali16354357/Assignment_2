# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              41000    Diesel       Manual      First    19.67  1582.0
# 1              46000    Petrol       Manual      First    13.00  1199.0
# 2              87000    Diesel       Manual      First    20.77  1248.0
# 3              40670    Diesel    Automatic     Second    15.20  1968.0
# 4              86999    Diesel       Manual      First    23.08  1461.0
#
#     Power  Seats  New_Price  Price
# 0  126.20    5.0        NaN  12.50
# 1   88.70    5.0  8.61 Lakh   4.50
# 2   88.76    7.0        NaN   6.00
# 3  140.80    5.0        NaN  17.74
# 4   63.10    5.0        NaN   3.50

# %% [markdown]
# # (B)

# %%
df['Mileage'] = df['Mileage'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
df['Engine'] = df['Engine'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
df['Power'] = df['Power'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
df['New_Price'] = df['New_Price'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              41000    Diesel       Manual      First    19.67  1582.0
# 1              46000    Petrol       Manual      First    13.00  1199.0
# 2              87000    Diesel       Manual      First    20.77  1248.0
# 3              40670    Diesel    Automatic     Second    15.20  1968.0
# 4              86999    Diesel       Manual      First    23.08  1461.0
#
#     Power  Seats  New_Price  Price
# 0  126.20    5.0        NaN  12.50
# 1   88.70    5.0       8.61   4.50
# 2   88.76    7.0        NaN   6.00
# 3  140.80    5.0        NaN  17.74
# 4   63.10    5.0        NaN   3.50

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %% [markdown]
# # (A)

# %%
missing_values = df.isnull().sum()
print("Missing_values_in_each_column:\n", missing_values)
# Out:
# Missing_values_in_each_column:
#  Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %%
df['Mileage'].fillna(df['Mileage'].median(),inplace=True)
df['Engine'].fillna(df['Engine'].median(),inplace=True)
df['Power'].fillna(df['Power'].median(),inplace=True)

df['Seats'].fillna(df['Seats'].mode()[0],inplace=True)

df.drop('New_Price', axis=1, inplace=True)
# Out:
# <ipython-input-42-bf2f876a671e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Mileage'].fillna(df['Mileage'].median(),inplace=True)
# <ipython-input-42-bf2f876a671e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine'].fillna(df['Engine'].median(),inplace=True)
# <ipython-input-42-bf2f876a671e>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Power'].fillna(df['Power'].median(),inplace=True)
# <ipython-input-42-bf2f876a671e>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Seats'].fillna(df['Seats'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              41000    Diesel       Manual      First    19.67  1582.0
# 1              46000    Petrol       Manual      First    13.00  1199.0
# 2              87000    Diesel       Manual      First    20.77  1248.0
# 3              40670    Diesel    Automatic     Second    15.20  1968.0
# 4              86999    Diesel       Manual      First    23.08  1461.0
#
#     Power  Seats  Price
# 0  126.20    5.0  12.50
# 1   88.70    5.0   4.50
# 2   88.76    7.0   6.00
# 3  140.80    5.0  17.74
# 4   63.10    5.0   3.50

# %% [markdown]
# #(C)

# %%
df['Fuel_Type'].replace({'Diesel': 0, 'Petrol': 1, 'Electric': 2}, inplace=True)
df['Transmission'].replace({'Manual': 0, 'Automatic': 1}, inplace=True)
# Out:
# <ipython-input-45-caee3d638869>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fuel_Type'].replace({'Diesel': 0, 'Petrol': 1, 'Electric': 2}, inplace=True)
# <ipython-input-45-caee3d638869>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Fuel_Type'].replace({'Diesel': 0, 'Petrol': 1, 'Electric': 2}, inplace=True)
# <ipython-input-45-caee3d638869>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Transmission'].replace({'Manual': 0, 'Automatic': 1}, inplace=True)
# <ipython-input-45-caee3d638869>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Transmission'].replace({'Manual': 0, 'Automatic': 1}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#     Power  Seats  Price
# 0  126.20    5.0  12.50
# 1   88.70    5.0   4.50
# 2   88.76    7.0   6.00
# 3  140.80    5.0  17.74
# 4   63.10    5.0   3.50

# %% [markdown]
# # (D)

# %%
from datetime import datetime

# %%
now = datetime.now().year

df['Car_Age'] = now - df['Year']

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#     Power  Seats  Price  Car_Age
# 0  126.20    5.0  12.50        9
# 1   88.70    5.0   4.50       13
# 2   88.76    7.0   6.00       12
# 3  140.80    5.0  17.74       11
# 4   63.10    5.0   3.50       11

# %% [markdown]
# # (E)

# %%
selected_columns = df[['Fuel_Type', 'Transmission']]

# %%
selected_columns.head()
# Out:
#    Fuel_Type  Transmission
# 0          0             0
# 1          1             0
# 2          0             0
# 3          0             1
# 4          0             0

# %%
selected_columns.head()
# Out:
#    Fuel_Type  Transmission
# 0          0             0
# 1          1             0
# 2          0             0
# 3          0             1
# 4          0             0

# %%
filter_data = df[df['Year'] > 2010]

# %%
filter_data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#     Power  Seats  Price  Car_Age
# 0  126.20    5.0  12.50        9
# 1   88.70    5.0   4.50       13
# 2   88.76    7.0   6.00       12
# 3  140.80    5.0  17.74       11
# 4   63.10    5.0   3.50       11

# %%
df.rename(columns={'Location': 'Place_Manufactured', 'Power': 'Horsepower'}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0                              Name Place_Manufactured  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option               Pune  2015
# 1           2                      Honda Jazz V            Chennai  2011
# 2           3                 Maruti Ertiga VDI            Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic         Coimbatore  2013
# 4           6            Nissan Micra Diesel XV             Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#    Horsepower  Seats  Price  Car_Age
# 0      126.20    5.0  12.50        9
# 1       88.70    5.0   4.50       13
# 2       88.76    7.0   6.00       12
# 3      140.80    5.0  17.74       11
# 4       63.10    5.0   3.50       11

# %%
arranged_data = df.sort_values(by='Mileage')

# %%
arranged_data.head()
# Out:
#       Unnamed: 0                                 Name Place_Manufactured  \
# 186          194                   Honda City 1.5 GXI          Ahmedabad
# 5225        5374  Mercedes-Benz M-Class ML 350 4Matic          Ahmedabad
# 1309        1354               Hyundai Santro Xing GL              Kochi
# 683          707  Mercedes-Benz M-Class ML 350 4Matic               Pune
# 723          749         Land Rover Range Rover 3.0 D             Mumbai
#
#       Year  Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  \
# 186   2007              60006          1             0      First      0.0
# 5225  2012              66000          0             1      First      0.0
# 1309  2011              20842          1             0      First      0.0
# 683   2014             120000          0             1      First      0.0
# 723   2008              55001          0             1     Second      0.0
#
#       Engine  Horsepower  Seats  Price  Car_Age
# 186   1497.0        98.6    5.0   2.95       17
# 5225  2987.0       165.0    5.0  23.00       12
# 1309  1086.0        62.0    5.0   2.78       13
# 683   2987.0       165.0    5.0  30.00       10
# 723   1497.0        98.6    5.0  26.50       16

# %%
summary = df.groupby('Fuel_Type')['Horsepower'].mean().reset_index()

# %%
summary.head()
# Out:
#    Fuel_Type  Horsepower
# 0          0  127.828966
# 1          1   97.123066
# 2          2   57.000000

# %%
df['Mileage_per_CC'] = df['Mileage'] / df['Engine']

# %%
df.head()
# Out:
#    Unnamed: 0                              Name Place_Manufactured  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option               Pune  2015
# 1           2                      Honda Jazz V            Chennai  2011
# 2           3                 Maruti Ertiga VDI            Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic         Coimbatore  2013
# 4           6            Nissan Micra Diesel XV             Jaipur  2013
#
#    Kilometers_Driven  Fuel_Type  Transmission Owner_Type  Mileage  Engine  \
# 0              41000          0             0      First    19.67  1582.0
# 1              46000          1             0      First    13.00  1199.0
# 2              87000          0             0      First    20.77  1248.0
# 3              40670          0             1     Second    15.20  1968.0
# 4              86999          0             0      First    23.08  1461.0
#
#    Horsepower  Seats  Price  Car_Age  Mileage_per_CC
# 0      126.20    5.0  12.50        9        0.012434
# 1       88.70    5.0   4.50       13        0.010842
# 2       88.76    7.0   6.00       12        0.016643
# 3      140.80    5.0  17.74       11        0.007724
# 4       63.10    5.0   3.50       11        0.015797
